# %% [markdown]
# <a href="https://colab.research.google.com/github/SwaksharDebnath/CRF-for-Bangla-Ancholik-NER-/blob/main/crf_for_barishal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install sbnltk
# !pip install simpletransformers
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 87.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.6 MB/s eta 0:00:00
# ...
#   Created wheel for sbnltk: filename=sbnltk-2.0.2-py3-none-any.whl size=31768 sha256=c09434e3f2836fdce32548a5a32d2f34db00ea61aa5639ef0ba6a2257dfece47
#   Stored in directory: /root/.cache/pip/wheels/38/86/99/309b28f346c48048db96b9a7b3b50b3f7462403e29fc1810a4
# Successfully built sbnltk
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.3 MB/s eta 0:00:00
# ...

# %%
# !pip install scikit-learn

# %%
from sklearn.cluster import KMeans

# %%
import numpy as np
import string

punctuations = list(string.punctuation) + ['।']
print(punctuations)
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', '।']

# %%
def load_data(filename):
    with open(filename, 'r',encoding='utf-8') as f:
        data = [line.strip().split(' _ _ ') for line in f.readlines()]

        sentences = []
        cur = []
        for line in data:
            if line == ['']:
                cur = [tuple(line) for line in cur]
                sentences.append(cur)
                cur = []
            else:

                if len(line[0]) == 0:
                    line[0] = ' '
                cur.append(line)
        sentences.append(cur)
        return sentences

# %%
def load_words(filename):
    with open(filename, 'r',encoding='utf-8') as f:
        data = [line.strip().split(' _ _ ') for line in f.readlines()]
        words = []
        for line in data:
            if line == ['']:
                continue
            else:
                words.append(line[0])
        # # convert each list to a tuple
        return list(set(words))

# %%
train_words_set = load_words('/content/drive/MyDrive/NER_Dataset/ConvertedTxtData/train/Barishal_NER_train.txt')
test_words_set = load_words('/content/drive/MyDrive/NER_Dataset/ConvertedTxtData/test/Barishal_NER_test.txt')

# %%
len(test_words_set), test_words_set[:10]
# Out:
# (1515,
#  ['খেলমু',
#   'বেবাক',
#   'দায়িত্ব',
#   'পলাইয়া',
#   'রে',
#   'লাগবেনা',
#   'কইলো',
#   'কারো',
#   'মানেরে',
#   'রোনালদো'])

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 2.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pybind11-3.0.4-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached pybind11-3.0.4-py3-none-any.whl (314 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp312-cp312-linux_x86_64.whl size=4653912 sha256=0a795754fe676938d703f8ed8d8fe6702eba33197512fe6fcca54ba6c3954409
#   Stored in directory: /root/.cache/pip/wheels/20/27/95/a7baf1b435f1cbde017cabdf1e9688526d2b0e929255a359c6
# Successfully built fasttext
# ...

# %%
from sbnltk.word_embedding import gensim_word2vec_embedding
w2v=gensim_word2vec_embedding()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=142XvJg9xdpgzuYD31Y4pm-ZVdMaWmtuq
# To: /usr/local/lib/python3.12/dist-packages/sbnltk/dataset/download_link.txt
# 100%|██████████| 1.66k/1.66k [00:00<00:00, 5.28MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1gF_b0a9BgroO8FpPUWWuSsCDeawYgEsb
# From (redirected): https://drive.google.com/uc?id=1gF_b0a9BgroO8FpPUWWuSsCDeawYgEsb&confirm=t&uuid=798bccf0-a2de-4e07-b220-184da5c2e0c1
# To: /usr/local/lib/python3.12/dist-packages/sbnltk/model/gensim_w2v.txt
# 100%|██████████| 1.89G/1.89G [00:27<00:00, 67.7MB/s]

# %%
def get_w2v(words):
    ret = []
    for word in words:
        ret.append(w2v.get_vector(word))
    return np.asarray(ret)

def get_cluster_id(words):
    words_w2v = get_w2v(words)
    kmeans = KMeans(n_clusters=500, random_state=0).fit(words_w2v)
    return kmeans.labels_, kmeans

# %%
train_words_w2v = get_w2v(train_words_set)

# %%
test_words_w2v = get_w2v(test_words_set)

# %%
kmeans = KMeans(n_clusters=500, random_state=0).fit(train_words_w2v)

# %%
kmeans.labels_
# Out:
# array([329,  76,  18, ...,   0,   0,   0], dtype=int32)

# %%
kmeans.predict(train_words_w2v[0:2])
# Out:
# array([329,  76], dtype=int32)

# %%
train = load_data('/content/drive/MyDrive/NER_Dataset/ConvertedTxtData/train/Barishal_NER_train.txt')

# %%
test = load_data('/content/drive/MyDrive/NER_Dataset/ConvertedTxtData/test/Barishal_NER_test.txt')

# %%
# !pip install bnlp_toolkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/sagorbrur/bnlp
# Out:
# Cloning into 'bnlp'...
# remote: Enumerating objects: 2353, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 2353 (delta 64), reused 93 (delta 34), pack-reused 2193 (from 3)
# Receiving objects: 100% (2353/2353), 23.17 MiB | 13.89 MiB/s, done.
# Resolving deltas: 100% (1334/1334), done.

# %%
from bnlp import BengaliPOS

bn_pos = BengaliPOS(model_path="bnlp/model/bn_pos.pkl")

text = "আমি ভাত খাই।" # or you can pass ['আমি', 'ভাত', 'খাই', '।']
res = bn_pos.tag(text)
print(res)
# Out:
# punkt not found. downloading...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [('আমি', 'PPR'), ('ভাত', 'NC'), ('খাই', 'VM'), ('।', 'PU')]

# %%
train[0]
# Out:
# [('শুক্কুরবার', 'O'), ('মুই', 'O'), ('ওইহানে', 'O'), ('যামু', 'O')]

# %%
def add_pos(sentence):
    # first one of the tuple is the word and the second one is the ner
    words = []
    for word in sentence:
        words.append(word[0])
    words = " ".join(words)
    # print(words)
    pos = bn_pos.tag(words)
    ## add ner back to the tuple
    ret = []
    for i in range(len(pos)):
        word = sentence[i][0]
        ner = sentence[i][1]
        ret.append((word, pos[i][1], ner))
    return ret

def add_pos_to_all(sents):
    ret = []
    for i in range(len(sents)):
        if i % 100 == 0:
            print(i)
        ret.append(add_pos(sents[i]))
    return ret

# %%
add_pos(train[0])
# Out:
# [('শুক্কুরবার', 'NC', 'O'),
#  ('মুই', 'NC', 'O'),
#  ('ওইহানে', 'NC', 'O'),
#  ('যামু', 'PU', 'O')]

# %%
train_sents =  add_pos_to_all(train)

# %%
test_sents = add_pos_to_all(test)

# %%
train_sents[3]

# %%
test_sents[0]

# %%
def get_all_words(sents):
    words = []
    for i in range(len(sents)):
        for w in sents[i]:
            words += [w[0]]
    return words

# %%
all_train_words = get_all_words(train_sents)
len(all_train_words)

# %%
word_freq = {}
for w in all_train_words:
    if w in word_freq:
        word_freq[w] += 1
    else:
        word_freq[w] = 1

# %%
## feature extraction for Conditional Random Field - Bangla NER
def wordToFeatures(sent, idx):
    word = sent[idx][0]
    postag = sent[idx][1]

    cluster_id = kmeans.predict([w2v.get_vector(word)])[0]
    features = {
        'bias': 1.0,
        'word': word,
        'cluster_id': cluster_id,
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word[:3]': word[:3],
        'word[:2]': word[:2],
        'word.isdigit': word.isdigit(),
        'index': idx,
        'length': len(word),
        'postag': postag,
        'freq': word_freq[word] if word in word_freq else 0,
    }


    for i in range(1, 3):
        if idx < i:
            break
        wordi = sent[idx-i][0]
        postagi = sent[idx-i][1]
        cluster_id_i = kmeans.predict([w2v.get_vector(wordi)])[0]
        features.update({
            '-{}:word'.format(i): wordi,
            '-{}:cluster_id'.format(i): cluster_id_i,
            '-{}:word[-3:]'.format(i): wordi[-3:],
            '-{}:word[-2:]'.format(i): wordi[-2:],
            '-{}:word[:3]'.format(i): wordi[:3],
            '-{}:word[:2]'.format(i): wordi[:2],
            '-{}:word.isdigit'.format(i): wordi.isdigit(),
            '-{}:postag'.format(i): postagi,
        })

    for i in range(1, 3):
        if (idx+i) >= len(sent):
            break
        wordi = sent[idx+i][0]
        postagi = sent[idx+i][1]
        cluster_id_i = kmeans.predict([w2v.get_vector(wordi)])[0]
        features.update({
            '{}:word'.format(i): wordi,
            '{}:cluster_id'.format(i): cluster_id_i,
            '{}:word[-3:]'.format(i): wordi[-3:],
            '{}:word[-2:]'.format(i): wordi[-2:],
            '{}:word[:3]'.format(i): wordi[:3],
            '{}:word[:2]'.format(i): wordi[:2],
            '{}:word.isdigit'.format(i): wordi.isdigit(),
            '{}:postag'.format(i): postagi,
        })

    if idx == 0:
        features['BOS'] = True
    if idx == len(sent) - 1:
        features['EOS'] = True

    return features

def sentTofeatures(sent):
    return [wordToFeatures(sent, i) for i in range(len(sent))]

def sentTolabels(sent):
    return [label for token, postag, label in sent]

# %%
X_train = [sentTofeatures(s) for s in train_sents]
y_train = [sentTolabels(s) for s in train_sents]

# %%
X_train[0][3]

# %%
# %%time
X_test = [sentTofeatures(s) for s in test_sents]
y_test = [sentTolabels(s) for s in test_sents]

# %%
import nltk
import sklearn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelBinarizer
import sklearn_crfsuite as crfsuite
from sklearn_crfsuite import metrics

# %%
crf = crfsuite.CRF(
    verbose='true',
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=150,
    all_possible_transitions=True
)
try:
    crf.fit(X_train, y_train, X_dev=X_test, y_dev=y_test)
except:
    pass

# %%
labels = list(crf.classes_)
labels

# %%
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred,
                      average='macro', labels=labels)
